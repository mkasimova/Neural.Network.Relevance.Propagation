# %%
import numpy as np

wd = '/media/mkasimova/Data2/NN_VSD/toy_model/testing.different.toy.models/'
subdir = 'final.8/'

fid = ['ROC.MLP.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.KL.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.PCA.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.RF.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.MLP.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.KL.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.PCA.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.RF.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.MLP.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_2e-1.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.KL.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_2e-1.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.PCA.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_2e-1.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.RF.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_2e-1.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.MLP.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_2e-1.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.KL.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_2e-1.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.PCA.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_2e-1.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.RF.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_2e-1.dis_0.1.constant_and_random.FIL_Median.']

results = np.zeros((4,4,3))

count = 0
for file_name in fid:
    for i in np.arange(1,4,1):
        auc = 0
        data = np.loadtxt(wd+subdir+file_name+str(i)+'.dat')
        for j in range(data.shape[0]-1):
            auc += (data[j+1,0]-data[j,0])*(data[j+1,1]+data[j,1])/2
        results[count%4,int(count/4),i-1] = auc
    count += 1

import matplotlib.pyplot as plt

plt.figure(figsize=(16,3.5))
for i in range(4):
    plt.subplot(1,4,i+1)
    plt.plot(results[:,i,:],'ro-')
    plt.xlim([-0.5,3.5])
    plt.ylim([0.85,1.05])
    plt.plot(np.arange(-1,5,1),6*[1])

plt.show()

# %%
import numpy as np

wd = '/media/mkasimova/Data2/NN_VSD/toy_model/testing.different.toy.models/'
subdir = 'final.9/'

fid = ['ROC.MLP.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.KL.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.PCA.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.RF.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.MLP.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.KL.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.PCA.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.RF.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.MLP.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_1e-1.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.KL.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_1e-1.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.PCA.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_1e-1.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.RF.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_1e-1.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.MLP.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_1e-1.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.KL.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_1e-1.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.PCA.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_1e-1.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.RF.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_1e-1.dis_0.1.constant_and_random.FIL_Median.']

results = np.zeros((4,4,3))

count = 0
for file_name in fid:
    for i in np.arange(1,4,1):
        auc = 0
        data = np.loadtxt(wd+subdir+file_name+str(i)+'.dat')
        for j in range(data.shape[0]-1):
            auc += (data[j+1,0]-data[j,0])*(data[j+1,1]+data[j,1])/2
        results[count%4,int(count/4),i-1] = auc
    count += 1

plt.figure(figsize=(16,3.5))
for i in range(4):
    plt.subplot(1,4,i+1)
    plt.plot(results[:,i,:],'ro-')
    plt.xlim([-0.5,3.5])
    plt.ylim([0.85,1.05])
    plt.plot(np.arange(-1,5,1),6*[1])

plt.show()

# %%
import numpy as np

wd = '/media/mkasimova/Data2/NN_VSD/toy_model/testing.different.toy.models/'
subdir = 'final.10/'

fid = ['ROC.MLP.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.KL.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.PCA.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.RF.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.MLP.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.KL.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.PCA.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.RF.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.MLP.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_1e-1.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.KL.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_1e-1.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.PCA.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_1e-1.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.RF.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_1e-1.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.MLP.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_1e-1.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.KL.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_1e-1.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.PCA.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_1e-1.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.RF.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_1e-1.dis_0.1.constant_and_random.FIL_Median.']

results = np.zeros((4,4,3))

count = 0
for file_name in fid:
    for i in np.arange(1,4,1):
        auc = 0
        data = np.loadtxt(wd+subdir+file_name+str(i)+'.dat')
        for j in range(data.shape[0]-1):
            auc += (data[j+1,0]-data[j,0])*(data[j+1,1]+data[j,1])/2
        results[count%4,int(count/4),i-1] = auc
    count += 1

plt.figure(figsize=(16,3.5))
for i in range(4):
    plt.subplot(1,4,i+1)
    plt.plot(results[:,i,:],'ro-')
    plt.xlim([-0.5,3.5])
    plt.ylim([0.85,1.05])
    plt.plot(np.arange(-1,5,1),6*[1])

plt.show()

# %%
import numpy as np

wd = '/media/mkasimova/Data2/NN_VSD/toy_model/testing.different.toy.models/'
subdir = 'final.11/'

fid = ['ROC.MLP.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.KL.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.PCA.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.RF.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.MLP.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.KL.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.PCA.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.RF.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_1e-2.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.MLP.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_1e-1.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.KL.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_1e-1.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.PCA.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_1e-1.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.RF.na_100.clu_2.[12_12].nfra_1200.noi_na_None.noi_1e-1.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.MLP.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_1e-1.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.KL.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_1e-1.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.PCA.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_1e-1.dis_0.1.constant_and_random.FIL_Median.',\
       'ROC.RF.na_100.clu_2.[12_12].nfra_1200.noi_na_12.noi_1e-1.dis_0.1.constant_and_random.FIL_Median.']


results = np.zeros((4,4,3))

count = 0
for file_name in fid:
    for i in np.arange(1,4,1):
        auc = 0
        data = np.loadtxt(wd+subdir+file_name+str(i)+'.dat')
        for j in range(data.shape[0]-1):
            auc += (data[j+1,0]-data[j,0])*(data[j+1,1]+data[j,1])/2
        results[count%4,int(count/4),i-1] = auc
    count += 1

plt.figure(figsize=(16,3.5))
for i in range(4):
    plt.subplot(1,4,i+1)
    plt.plot(results[:,i,:],'ro-')
    plt.xlim([-0.5,3.5])
    plt.ylim([0.85,1.05])
    plt.plot(np.arange(-1,5,1),6*[1])

plt.show()
